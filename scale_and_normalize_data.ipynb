# %% [markdown]
# **Scaling** changes the range of data. You want to scale data when you're using methods based on measures of how far apart data points, like SVM or KNN. With these algorithms, a change of "1" in any numeric feature is given the same importance.

# %%
import pandas as pd
import numpy as np
from scipy import stats
from mlxtend.preprocessing import minmax_scaling
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("data/ks-projects-201801.csv")

# %%
goal = data.goal
scaled_goal = minmax_scaling(goal, columns=[0])
fix, ax = plt.subplots(1, 2)
sns.distplot(goal, ax=ax[0])
ax[0].set_title("Original data")
sns.distplot(scaled_goal, ax=ax[1])
ax[1].set_title("Scaled data")
# Out:
# Text(0.5,1,'Scaled data')

# %% [markdown]
# **Normalization** changes the shape of the distribution of data.The point of normalization is to change your observations so that they can be described as a normal distribution.In general, you'll only want to normalize your data if you're going to be using a machine learning or statistics technique that assumes your data is normally distributed. Some examples of these include t-tests, ANOVAs, linear regression, linear discriminant analysis (LDA) and Gaussian naive Bayes.

# %%
pledged = data.pledged
positive_pledged_index = data.pledged > 0
positive_pledged = pledged.loc[positive_pledged_index]

normalized_pledged = stats.boxcox(positive_pledged)[0]
fig, ax = plt.subplots(1, 2)
sns.distplot(pledged, ax=ax[0])
ax[0].set_title("original data")
sns.distplot(normalized_pledged, ax=ax[1])
ax[1].set_title("normalized data")
# Out:
# Text(0.5,1,'normalized data')
